# %%
#read pkl
import pickle
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def read_pkl(file):
    with open(file, 'rb') as f:
        data = pickle.load(f)
    return data

read_pkl(r'D:\medina_alpha_research\GA\Data\target.pkl')
# Out:
# symbol          1101      1102      1103      1104      1108      1109  \
# datetime
# 2013-05-15  0.006338 -0.001318  0.003766  0.000000  0.000000 -0.004674
# 2013-05-16 -0.005041  0.000000  0.003740  0.002754 -0.002831 -0.004695
# 2013-05-17 -0.006330 -0.003959  0.007464  0.005482  0.007096 -0.004718
# 2013-05-20  0.006371  0.003975  0.014817  0.000000  0.009843  0.014220
# 2013-05-21  0.005067 -0.002640  0.010945  0.002721  0.034867  0.004674
# ...              ...       ...       ...       ...       ...       ...
# 2024-08-08  0.014706  0.022432  0.017442 -0.006494  0.025806  0.002865
# 2024-08-09 -0.001449  0.004619  0.011429  0.017974  0.000000 -0.002857
# 2024-08-12  0.004354  0.002299  0.014124 -0.017657  0.000000  0.000000
# 2024-08-13 -0.028902  0.013761 -0.008357  0.009804  0.006289  0.040115
# 2024-08-14       NaN       NaN       NaN       NaN       NaN       NaN
#
# symbol          1110      1201      1203      1210  ...      9944      9945  \
# ...
